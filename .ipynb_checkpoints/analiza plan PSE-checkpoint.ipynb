# %%
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt

import datetime

import sqlite3

import requests
from bs4 import BeautifulSoup

import os
import sys

# %%
moc_os_dict = {"elektrownie": ["węgiel kamienny", 
                               "węgiel brunatny",
                               "gazowe" , "wodne", 
                               "wiatrowe", 
                               "biogaz/biomasa", 
                               "słoneczne", 
                               "inne"],
            "moc 2020": [24289.532, 
                         8456.4,
                         3154.949,
                         2403.5,
                         6347.651,
                         1055.653,
                         3960.042,
                         574.1],
             "moc 2021": [23031.472, 
                          8397.4, 
                          3309.409, 
                          2406.9, 
                          7007.697, 
                          1069.004, 
                          7681.368, 
                          574.1  ], 
              "moc 2022": [22436.344, 
                           8269.4,
                           3845.905,
                           2408.2,
                           8129.465,
                           1120.998,
                           12114.696,
                           574.1 ], 
}

# %%
moc_os_dict
# Out:
# {'elektrownie': ['węgiel kamienny',
#   'węgiel brunatny',
#   'gazowe',
#   'wodne',
#   'wiatrowe',
#   'biogaz/biomasa',
#   'słoneczne',
#   'inne'],
#  'moc 2020': [24289.532,
#   8456.4,
#   3154.949,
#   2403.5,
#   6347.651,
#   1055.653,
#   3960.042,
#   574.1],
#  'moc 2021': [23031.472,
#   8397.4,
#   3309.409,
#   2406.9,
#   7007.697,
#   1069.004,
#   7681.368,
#   574.1],
#  'moc 2022': [22436.344,
#   8269.4,
#   3845.905,
#   2408.2,
#   8129.465,
#   1120.998,
#   12114.696,
#   574.1]}

# %%
df_moc = pd.DataFrame(moc_os_dict)

# %%
df_moc = df_moc.sort_values('moc 2021', ascending=False)

# %%
fig, axs = plt.subplots(1, 2, figsize = (8,5))
#colors=sns.color_palette("RdGy",8)
#labels = df_moc['elektrownie']
colors = ["#443F40", "#714036", "#FFF222", "#83E370","#1F6389", "#5DBDF5", "#8C959A", "#D18835"]

values1 = df_moc['moc 2020']
axs[0].pie(values1, autopct='%1.1f%%', pctdistance=1.2, colors=colors)
axs[0].set_title('Moc osiągalna w 2020')


values2 = df_moc['moc 2022']
axs[1].pie(values2, autopct='%1.1f%%',pctdistance=1.2, colors=colors)
axs[1].set_title('Moc osiągalna w 2022')


plt.legend(df_moc['elektrownie'], loc="lower center", bbox_to_anchor=(0, -0.2), ncol=8)
plt.show()

# %% [markdown]
# Struktrę mocy osiągalnej w Polskim Systemie Elektroenergetycznym w roku 2020 i 2022 przedstawiają poniższe wykresy.
# Zauważalny jest wyraźny wzrost źródeł fotowoltaicznych, natomiast spadek źródel węglowych. Moc

# %% [markdown]
# W kwietniu 2022 r. Agencja Rynku Energii poinformowała, że moc zainstalowanych żródeł fotowoltaicznych wyniosła na koniec lutego prawie 8,8 GW – dwukrotnie więcej niż w lutym 2021 r. Rosnąca moc źródeł niesterowalnych wprowadza nowe wyzwania dla utrzymania odpowiedniego zbilansowania w sieci przesyłowej. W marcu 2022 r. PSE zrealizowało pierwsze w historii ograniczenie generacji źródeł wiatrowych ze względu na nadwyżkę wytwarzania ponad zapotrzebowanie w Krajowej Sieci Elektroenergetyczne.
# Ze względów technicznych wyłączenie jednostek konwencjonalnych jest trudne lub często niemożliwe do realizacji, co sprawiło, że pomimo znacznie niższych kosztów krańcowych odłączono moce wiatrowe. Według PSE takie sytuacje będą w przyszłości pojawiać się coraz częściej, szczególnie w dni sprzyjające produkcji z OZE oraz o niskim zapotrzebowaniu na energię w systemie.

# %% [markdown]
# Chociaż Polska szybko zbliża się do 60 GW mocy zainstalowanej, to pokrycie zapotrzebowania w wysokości 23 GW potrafi być problemem przy bezwietrznej pogodzie i znaczących ubytkach w elektrowniach węglowych

# %% [raw]
# opis danych:
# zap - Prognozowane zapotrzebowanie sieci
# rezerwa - Wymagana rezerwa mocy OSP
# nadwyżki OSP - Nadwyżka mocy dostępna dla OSP (7) + (9) - [(3) - (12)] - (13)
# moc JW i mag w RB - Moc dyspozycyjna JW i magazynów energii świadczących usługi bilansujące w ramach RB
# moc JW i mag w RB OSP - Moc dyspozycyjna JW i magazynów energii świadczących usługi bilansujące w ramach RB dostępna dla OSP
# gen JW i mag w RB - Przewidywana generacja JW i agazynów energii świadczących usługi bilansujące w ramach RB (3) - (9) - (12)
# gen JW i mag nie RB - Prognozowana generacja JW i magazynów energii nie świadczących usług bilansujących w ramach RB
# gen wiatr - Prognozowana sumaryczna generacja źródeł wiatrowych
# gen PV - Prognozowana sumaryczna generacja źródeł fotowoltaicznych
# wymiana - Planowane saldo wymiany międzysystemowej
# niedyspozycje - Prognozowana wielkość niedyspozycyjności wynikająca z ograniczeń sieciowych występujących w sieci przesyłowej oraz sieci dystrybucyjnej w zakresie dostarczania energii elektrycznej
# gen JW nieobjętych OM - Przewidywana generacja zasobów wytwórczych nieobjętych obowiązkami mocowymi
# OM JRM - Obowiązki mocowe wszystkich jednostek rynku mocy

# %%
os.listdir('plan_2023')
# Out:
# ['plan_012023.csv',
#  'plan_022023.csv',
#  'plan_032023.csv',
#  'plan_042023.csv',
#  'plan_052023.csv',
#  'plan_062023.csv',
#  'plan_072023.csv',
#  'plan_082023.csv',
#  'plan_092023.csv',
#  'plan_102023.csv',
#  'plan_112023.csv',
#  'plan_122023.csv']

# %%
csv_files = [file for file in os.listdir('plan_2023') if file.endswith('.csv')]

# %% [markdown]
# ### **Tu wpisałam ten encoding, bo inaczej wyskakiwał mi błąd - rozwiązanie z internetu **

# %%
# lista do połączenia tabel w jedną dla całego roku
csv_data_list = [pd.read_csv('plan_2023/'+file, sep=';', encoding='iso-8859-1') for file in csv_files]

# %%
plan_2023_oryginal = pd.concat(csv_data_list, axis=0, ignore_index=True)

# %%
plan_2023 = plan_2023_oryginal.copy()
plan_2023.head()
# Out:
#          Doba  Godzina  Prognozowane zapotrzebowanie sieci  \
# 0  2023-01-01        1                               11823
# 1  2023-01-01        2                               11031
# 2  2023-01-01        3                               11018
# 3  2023-01-01        4                               10678
# 4  2023-01-01        5                               10534
#
#    Wymagana rezerwa mocy OSP  \
# 0                       1294
# 1                       1280
# 2                       1286
# 3                       1259
# 4                       1230
#
#    Nadwy¿ka mocy dostêpna dla OSP (7) + (9) - [(3) - (12)] - (13)  \
# 0                                               2713
# 1                                               1615
# 2                                                183
# 3                                                305
# 4                                               1303
#
#    Moc dyspozycyjna JW i magazynów energii wiadcz¹cych us³ugi bilansuj¹ce w ramach RB  \
# 0                                              14578
# 1                                              14578
# 2                                              15266
# 3                                              14940
# 4                                              14627
#
#   Moc dyspozycyjna JW i magazynów energii wiadcz¹cych us³ugi bilansuj¹ce w ramach RB dostêpna dla OSP  \
# 0                                              7 342
# 1                                              7 342
# 2                                              8 029
# 3                                              7 704
# 4                                              7 391
#
#    Przewidywana generacja JW i magazynów energii wiadcz¹cych us³ugi bilansuj¹ce w ramach RB (3) - (9) - (12)  \
# 0                                               4628
# 1                                               5727
# 2                                               7846
# 3                                               7399
# 4                                               6088
#
#    Prognozowana generacja JW i magazynów energii nie wiadcz¹cych us³ug bilansuj¹cych w ramach RB  \
# 0                                               8303
# 1                                               6956
# 2                                               4826
# 3                                               5050
# 4                                               6000
#
#    Prognozowana sumaryczna generacja róde³ wiatrowych  \
# 0                                               5441
# 1                                               4059
# 2                                               2091
# 3                                               2296
# 4                                               3246
#
#    Prognozowana sumaryczna generacja róde³ fotowoltaicznych  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    Planowane saldo wymiany miêdzysystemowej  \
# 0                                     -1109
# 1                                     -1652
# 2                                     -1654
# 3                                     -1771
# 4                                     -1555
#
#    Prognozowana wielkoæ niedyspozycyjnoci wynikaj¹ca z ograniczeñ sieciowych wystêpuj¹cych w sieci przesy³owej oraz sieci dystrybucyjnej w zakresie dostarczania energii elektrycznej  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    Przewidywana generacja zasobów wytwórczych nieobjêtych obowi¹zkami mocowymi  \
# 0                                              11175
# 1                                               9809
# 2                                               8832
# 3                                               8499
# 4                                               9164
#
#    Obowi¹zki mocowe wszystkich jednostek rynku mocy
# 0                                                 0
# 1                                                 0
# 2                                                 0
# 3                                                 0
# 4                                                 0

# %% [markdown]
# # Przygotowanie danch

# %%
# Przygotowanie danych 
plan_2023=plan_2023.rename(columns={'Prognozowane zapotrzebowanie sieci':'zap',
                                  'Wymagana rezerwa mocy OSP':'rezerwa',
                                    'Nadwy¿ka mocy dostêpna dla OSP (7) + (9) - [(3) - (12)] - (13)':'nadwyżki OSP',
                                    'Moc dyspozycyjna JW i magazynów energii wiadcz¹cych us³ugi bilansuj¹ce w ramach RB':'moc JW i mag w RB',
                                    'Moc dyspozycyjna JW i magazynów energii wiadcz¹cych us³ugi bilansuj¹ce w ramach RB dostêpna dla OSP':'moc JW i mag w RB OSP',
                                    'Przewidywana generacja JW i magazynów energii wiadcz¹cych us³ugi bilansuj¹ce w ramach RB (3) - (9) - (12)':'gen JW i mag w RB',
                                    'Prognozowana generacja JW i magazynów energii nie wiadcz¹cych us³ug bilansuj¹cych w ramach RB':'gen JW i mag nie RB',
                                    'Prognozowana sumaryczna generacja róde³ wiatrowych':'gen wiatr',
                                    'Prognozowana sumaryczna generacja róde³ fotowoltaicznych':'gen PV',
                                    'Planowane saldo wymiany miêdzysystemowej':'wymiana',
                                    'Prognozowana wielkoæ niedyspozycyjnoci wynikaj¹ca z ograniczeñ sieciowych wystêpuj¹cych w sieci przesy³owej oraz sieci dystrybucyjnej w zakresie dostarczania energii elektrycznej':'niedyspozycje',
                                    'Przewidywana generacja zasobów wytwórczych nieobjêtych obowi¹zkami mocowymi':'gen JW nieobjętych OM',
                                    'Obowi¹zki mocowe wszystkich jednostek rynku mocy':'OM JRM',
                                 })
plan_2023.dtypes
# Out:
# Doba                     object
# Godzina                   int64
# zap                       int64
# rezerwa                   int64
# nadwyżki OSP              int64
# moc JW i mag w RB         int64
# moc JW i mag w RB OSP    object
# gen JW i mag w RB         int64
# gen JW i mag nie RB       int64
# gen wiatr                 int64
# gen PV                    int64
# wymiana                   int64
# niedyspozycje             int64
# gen JW nieobjętych OM     int64
# OM JRM                    int64
# dtype: object

# %%
plan_2023.head()
# Out:
#          Doba  Godzina    zap  rezerwa  nadwyżki OSP  moc JW i mag w RB  \
# 0  2023-01-01        1  11823     1294          2713              14578
# 1  2023-01-01        2  11031     1280          1615              14578
# 2  2023-01-01        3  11018     1286           183              15266
# 3  2023-01-01        4  10678     1259           305              14940
# 4  2023-01-01        5  10534     1230          1303              14627
#
#   moc JW i mag w RB OSP  gen JW i mag w RB  gen JW i mag nie RB  gen wiatr  \
# 0                 7 342               4628                 8303       5441
# 1                 7 342               5727                 6956       4059
# 2                 8 029               7846                 4826       2091
# 3                 7 704               7399                 5050       2296
# 4                 7 391               6088                 6000       3246
#
#    gen PV  wymiana  niedyspozycje  gen JW nieobjętych OM  OM JRM
# 0       0    -1109              0                  11175       0
# 1       0    -1652              0                   9809       0
# 2       0    -1654              0                   8832       0
# 3       0    -1771              0                   8499       0
# 4       0    -1555              0                   9164       0

# %%
# usunięcie jakiegoś białego znaku i połączenie w jedne ciąg
plan_2023['moc JW i mag w RB OSP']=["".join(row.split()) for row in plan_2023['moc JW i mag w RB OSP']]

# zmiania object na int 
plan_2023['moc JW i mag w RB OSP'] = plan_2023['moc JW i mag w RB OSP'].astype('int')



# zmiania formatu dat
plan_2023['Doba'] = pd.to_datetime(plan_2023['Doba']) # zmieniamy, aby potem korzystać z funkcji datowych 


# usunięcie wiersza, których 'Godz.' == 25 - jak nadac nowe indeksy w meijsce usuniętych ?
plan_2023.drop(plan_2023[plan_2023['Godzina']==25].index, inplace=True)


plan_2023.dtypes
# Out:
# Doba                     datetime64[ns]
# Godzina                           int64
# zap                               int64
# rezerwa                           int64
# nadwyżki OSP                      int64
# moc JW i mag w RB                 int64
# moc JW i mag w RB OSP             int32
# gen JW i mag w RB                 int64
# gen JW i mag nie RB               int64
# gen wiatr                         int64
# gen PV                            int64
# wymiana                           int64
# niedyspozycje                     int64
# gen JW nieobjętych OM             int64
# OM JRM                            int64
# dtype: object

# %%
plan_2023.head()
# Out:
#         Doba  Godzina    zap  rezerwa  nadwyżki OSP  moc JW i mag w RB  \
# 0 2023-01-01        1  11823     1294          2713              14578
# 1 2023-01-01        2  11031     1280          1615              14578
# 2 2023-01-01        3  11018     1286           183              15266
# 3 2023-01-01        4  10678     1259           305              14940
# 4 2023-01-01        5  10534     1230          1303              14627
#
#    moc JW i mag w RB OSP  gen JW i mag w RB  gen JW i mag nie RB  gen wiatr  \
# 0                   7342               4628                 8303       5441
# 1                   7342               5727                 6956       4059
# 2                   8029               7846                 4826       2091
# 3                   7704               7399                 5050       2296
# 4                   7391               6088                 6000       3246
#
#    gen PV  wymiana  niedyspozycje  gen JW nieobjętych OM  OM JRM
# 0       0    -1109              0                  11175       0
# 1       0    -1652              0                   9809       0
# 2       0    -1654              0                   8832       0
# 3       0    -1771              0                   8499       0
# 4       0    -1555              0                   9164       0

# %% [markdown]
# # Analiza danych

# %% [markdown]
# ## Przewidywane zapotrzebowanie na moc na rok w 2023

# %%
# max zapotrzebowanie każdego dnia

plan_2023.groupby('Doba', as_index=False)['zap'].max()['zap']
# Out:
# 0      15515
# 1      20276
# 2      20822
# 3      21685
# 4      21227
#        ...
# 360    24001
# 361    24094
# 362    23537
# 363    21140
# 364    17508
# Name: zap, Length: 365, dtype: int64

# %%
#jak dodać kolumnę z sezonem ? 

for index, row in plan_2023.iterrows():
    if (row['Doba'] >= '01.04.2023') & (row['Doba'] <= '30.09.2023') :
        plan_2023.loc[index,'sezon'] = 'lato'
        print (plan_2023.loc[index,'sezon'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14292\92296280.py in <module>
#       2
#       3 for index, row in plan_2023.iterrows():
# ----> 4     if (row['Doba'] >= '01.04.2023') & (row['Doba'] <= '30.09.2023') :
#       5         plan_2023.loc[index,'sezon'] = 'lato'
#       6         print (plan_2023.loc[index,'sezon'])
#
# TypeError: '>=' not supported between instances of 'Timestamp' and 'str'

# %%
#średnie zapotrzebowanie 

#srednie godziny z całego roku
srednie_godz=plan_2023.groupby('Godzina', as_index=False)['zap'].mean()

#srednie godziny z lata
lato = plan_2023[ (plan_2023['Doba']>='01.04.2023') & (plan_2023['Doba']<='30.09.2023') ]
srednie_godz_lato=lato.groupby('Godzina', as_index=False)['zap'].mean()

#srednie godziny z zimy
zima = plan_2023[ (plan_2023['Doba']<'01.04.2023') | (plan_2023['Doba']>'30.09.2023') ]
srednie_godz_zima=zima.groupby('Godzina', as_index=False)['zap'].mean()
# Out:
# C:\Users\Justyna\AppData\Local\Temp\ipykernel_14292\2178733086.py:7: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   lato = plan_2023[ (plan_2023['Doba']>='01.04.2023') & (plan_2023['Doba']<='30.09.2023') ]
# C:\Users\Justyna\AppData\Local\Temp\ipykernel_14292\2178733086.py:11: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   zima = plan_2023[ (plan_2023['Doba']<'01.04.2023') | (plan_2023['Doba']>'30.09.2023') ]

# %%
# dodadnie dni tygodnia

plan_2023['nr dnia tyg'] = plan_2023['Doba'].dt.weekday
plan_2023['dzień tyg']=plan_2023['Doba'].dt.day_name(locale= "pl_PL")

# dodanie miesięcy
plan_2023['month_start'] = plan_2023.Doba.dt.to_period('M').dt.to_timestamp()
plan_2023.sample(5)
# Out:
#            Doba  Godzina    zap  rezerwa  nadwyżki OSP  moc JW i mag w RB  \
# 6367 2023-09-23        9  16957     3052          6079              20710
# 5909 2023-09-04        7  17763     3197          6080              21499
# 4558 2023-07-09       24  14873     2677          6950              20390
# 7521 2023-11-10       10  22033     3966          3101              21239
# 1612 2023-03-09        5  17894     2505          8135              19610
#
#       moc JW i mag w RB OSP  gen JW i mag w RB  gen JW i mag nie RB  \
# 6367                  20710              14631                 2326
# 5909                  21499              15419                 2344
# 4558                  20390              13440                 1433
# 7521                  21239              18138                 3895
# 1612                  19610              11475                 6419
#
#       gen wiatr  gen PV  wymiana  niedyspozycje  gen JW nieobjętych OM  \
# 6367         15    1421        0              0                   1752
# 5909         23     433        0              0                   1682
# 4558         24       0        0              0                    949
# 7521         23    1150        0              0                   2645
# 1612       2302       0        0              0                   4305
#
#       OM JRM  nr dnia tyg     dzień tyg month_start
# 6367       0            5        Sobota  2023-09-01
# 5909       0            0  Poniedziałek  2023-09-01
# 4558       0            6     Niedziela  2023-07-01
# 7521   23510            4        Piątek  2023-11-01
# 1612       0            3      Czwartek  2023-03-01

# %%
# Wykres zapotrzebowania 

fig, axs = plt.subplots(1, 2, figsize = (20,6))
dayList  = srednie_godz['Godzina']

values1 = srednie_godz_lato['zap']
axs[0].plot(dayList, values1)
axs[0].set_title('Zapotrzebowanie na moc w sezonie letnim')

axs[0].set_ylim(15000, 22000)

axs[0].set_ylabel('MW')
axs[0].set_xlabel('Doba, h')


values2 = srednie_godz_zima['zap']
axs[1].plot(dayList, values2)
axs[1].set_title('Zapotrzebowanie na moc w sezonie zimowym')

axs[1].set_ylim(15000, 22000)

axs[1].set_ylabel('MW')
axs[1].set_xlabel('Doba, h')

plt.show()

# %% [markdown]
# ## Krajowa miesięczna produkcja i zużycie energii elektrycznej w 2023 roku.

# %% [markdown]
# ## Bilans mocy

# %% [markdown]
# niedobór wymaganej nadwyżki mocy (niedobór mocy) = wymagana rezerwa - nadwyżka mocy dostępna dla OSP
# wymagana rezerwa w KSE to 9% planowanego (prognozowanego przez OSP) zapotrzebowania do pokrycia przez elektrownie krajowe

# %%
plan_2023.head()
# Out:
#         Doba  Godzina    zap  rezerwa  nadwyżki OSP  moc JW i mag w RB  \
# 0 2023-01-01        1  11823     1294          2713              14578
# 1 2023-01-01        2  11031     1280          1615              14578
# 2 2023-01-01        3  11018     1286           183              15266
# 3 2023-01-01        4  10678     1259           305              14940
# 4 2023-01-01        5  10534     1230          1303              14627
#
#    moc JW i mag w RB OSP  gen JW i mag w RB  gen JW i mag nie RB  gen wiatr  \
# 0                   7342               4628                 8303       5441
# 1                   7342               5727                 6956       4059
# 2                   8029               7846                 4826       2091
# 3                   7704               7399                 5050       2296
# 4                   7391               6088                 6000       3246
#
#    gen PV  wymiana  niedyspozycje  gen JW nieobjętych OM  OM JRM
# 0       0    -1109              0                  11175       0
# 1       0    -1652              0                   9809       0
# 2       0    -1654              0                   8832       0
# 3       0    -1771              0                   8499       0
# 4       0    -1555              0                   9164       0

# %%
plan_2023['Niedobór mocy'] = plan_2023['rezerwa'] - plan_2023['nadwyżki OSP']

# %%
plan_2023.head()
# Out:
#         Doba  Godzina    zap  rezerwa  nadwyżki OSP  moc JW i mag w RB  \
# 0 2023-01-01        1  11823     1294          2713              14578
# 1 2023-01-01        2  11031     1280          1615              14578
# 2 2023-01-01        3  11018     1286           183              15266
# 3 2023-01-01        4  10678     1259           305              14940
# 4 2023-01-01        5  10534     1230          1303              14627
#
#    moc JW i mag w RB OSP  gen JW i mag w RB  gen JW i mag nie RB  gen wiatr  \
# 0                   7342               4628                 8303       5441
# 1                   7342               5727                 6956       4059
# 2                   8029               7846                 4826       2091
# 3                   7704               7399                 5050       2296
# 4                   7391               6088                 6000       3246
#
#    gen PV  wymiana  niedyspozycje  gen JW nieobjętych OM  OM JRM  \
# 0       0    -1109              0                  11175       0
# 1       0    -1652              0                   9809       0
# 2       0    -1654              0                   8832       0
# 3       0    -1771              0                   8499       0
# 4       0    -1555              0                   9164       0
#
#    Niedobór mocy
# 0          -1419
# 1           -335
# 2           1103
# 3            954
# 4            -73

# %%
(
    csv_data['orders']
    .merge(csv_data['order_details'], on='order_id')
    .merge(csv_data['pizzas'], on='pizza_id')
    .query("size == 'L'")
    .astype({'date': 'datetime64[ns]'})
    .assign(month = lambda x: x['date'].dt.strftime('%Y-%m'))
    .groupby('month', as_index=False)
    .agg(L_pizzas = ('quantity', 'sum'))
    .sort_values('L_pizzas', ascending=False)
    .head(3)
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14292\1232305988.py in <module>
#       1 (
# ----> 2     csv_data['orders']
#       3     .merge(csv_data['order_details'], on='order_id')
#       4     .merge(csv_data['pizzas'], on='pizza_id')
#       5     .query("size == 'L'")
#
# NameError: name 'csv_data' is not defined

# %%
(
    plan_2023
    .assign(miesiąc = lambda x: x['Doba'].dt.strftime('%Y-%m'))
    .groupby('miesiąc', as_index=False).mean()
    
)
# Out:
# C:\Users\Justyna\AppData\Local\Temp\ipykernel_14292\396975307.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   plan_2023
#     miesiąc    Godzina           zap      rezerwa  nadwyżki OSP  \
# 0   2023-01  12.500000  18456.177419  1851.396505   3140.010753
# 1   2023-02  12.500000  18783.843750  1879.001488   3810.151786
# 2   2023-03  12.484522  19112.306864  2959.177658   5795.683715
# 3   2023-04  12.500000  17942.651389  3229.677778   5217.250000
# 4   2023-05  12.500000  16845.059140  3032.114247   6900.248656
# 5   2023-06  12.500000  17476.147222  3145.704167   5664.934722
# 6   2023-07  12.500000  17594.887097  3167.079301   5440.084677
# 7   2023-08  12.500000  17176.106183  3091.685484   7451.591398
# 8   2023-09  12.500000  17888.048611  3219.822222   5831.363889
# 9   2023-10  12.500000  18736.060484  3372.494624   5730.001344
# 10  2023-11  12.500000  19669.126389  3540.427778   5981.819444
# 11  2023-12  12.500000  19993.674731  3598.862903   6707.967742
#
#     moc JW i mag w RB  moc JW i mag w RB OSP  gen JW i mag w RB  \
# 0        16533.662634           14261.341398       11101.591398
# 1        18892.251488           14685.492560       10725.828869
# 2        19959.788694           19430.738896       13456.445491
# 3        19803.158333           19803.158333       14511.531944
# 4        21379.694892           21379.694892       14267.705645
# 5        21072.972222           21072.972222       15244.970833
# 6        21040.686828           21040.686828       15573.630376
# 7        22429.592742           22429.592742       14972.524194
# 8        21417.127778           21417.127778       15585.772222
# 9        21472.352151           21472.352151       15742.341398
# 10       22051.936111           22051.936111       16069.333333
# 11       22945.595430           22945.595430       16237.607527
#
#     gen JW i mag nie RB    gen wiatr       gen PV     wymiana  niedyspozycje  \
# 0           7293.685484  3301.358871   269.719086   60.895161      19.732527
# 1           7810.482143  3329.833333   653.431548  247.553571     149.528274
# 2           5580.029610  1372.380888   765.161507   75.830417     178.660834
# 3           3431.127778    23.050000   878.079167    0.000000      74.266667
# 4           2577.375000    20.188172  1028.072581    0.000000     211.768817
# 5           2231.212500    14.645833  1127.258333    0.000000     163.200000
# 6           2021.259409    14.185484  1174.622312    0.000000      26.935484
# 7           2203.596774    13.845430  1052.049731    0.000000       5.491935
# 8           2302.265278    17.773611   835.665278    0.000000       0.000000
# 9           2993.725806    21.256720   529.036290    0.000000       0.000000
# 10          3599.758333    18.287500   317.961111    0.000000       0.816667
# 11          3756.056452    29.334677   213.521505    0.000000       0.000000
#
#     gen JW nieobjętych OM        OM JRM  Niedobór mocy
# 0            10037.701613   9997.862903   -1288.614247
# 1            10195.995536  10541.964286   -1931.150298
# 2             4587.495289  10964.777927   -2836.506057
# 3             2105.454167   9044.000000   -1987.572222
# 4             1767.935484   9673.548387   -3868.134409
# 5             1685.558333   9996.000000   -2519.230556
# 6             1592.857527   9651.108871   -2273.005376
# 7             1653.888441  10110.685484   -4359.905914
# 8             1680.947222   9972.812500   -2611.541667
# 9             1881.375000  10427.822581   -2357.506720
# 10            2166.012500  10285.625000   -2441.391667
# 11            2193.166667   9005.846774   -3109.104839

# %% [markdown]
# ### rezerwa

# %%
plt.figure(figsize = (10,5))

dayList  = plan_2023['Doba']
values_rezerwa = plan_2023['rezerwa']

plt.plot(dayList, values_rezerwa )
plt.ylabel('MW')
plt.ylim(0)
plt.title('rezerwa')


# tu zmienić, aby po prawej stronie był procent 

plt.show()

# %%
plan_2023['rezerwa'].max()
# Out:
# 4466

# %%
plan_2023['rezerwa'].min()
# Out:
# 1214

# %%
plan_2023['rezerwa %'] = plan_2023['rezerwa'] / plan_2023['zap']
plan_2023.head(1)
# Out:
#         Doba  Godzina    zap  rezerwa  nadwyżki OSP  moc JW i mag w RB  \
# 0 2023-01-01        1  11823     1294          2713              14578
#
#    moc JW i mag w RB OSP  gen JW i mag w RB  gen JW i mag nie RB  gen wiatr  \
# 0                   7342               4628                 8303       5441
#
#    gen PV  wymiana  niedyspozycje  gen JW nieobjętych OM  OM JRM  \
# 0       0    -1109              0                  11175       0
#
#    Niedobór mocy  rezerwa %
# 0          -1419   0.109448

# %% [markdown]
# Na dostawie powyższego wykresu widzimy wyraźny podział na dwie głowne wielkości poziomów rezerw. Pierwszy waha się od 1200 do 2200 MW, a drugi od 2200 do 4000 MW. Skok wystepuje po 7 marca.
# Na dostawie powyższego wykresu widzimy wraźny skok przewidywanych rezerw mocy po 7 marca.
# wymagana rezerwa w KSE to 9% planowanego zapotrzebowania, więc aby ocenić z czego winika skok wykonany wykres pocentowy.
# Wykres procentowy pokazuje, że plan koorydnacyjny PSE zakłada wymóg rezerwy mocy na poziomie 18%.
# Poziom wymaganej nadwyżki mocy jest uzależniony od horyzontu planowania i dla planów opracowywanych w dobie D wynosi:
# Dla doby D oraz D+1: 9% planowanego (prognozowanego przez OSP) zapotrzebowania.
# Od doby D+2 do doby D+9 włącznie: 14% planowanego zapotrzebowania.
# Dla pozostałych dób horyzontu planowania PBM począwszy od doby D+10: 18% planowanego zapotrzebowania.

# %% [raw]
# for index, row in df_pop.iterrows():
#     if row['Population'] > 100:
#         df_pop.loc[index,'Size'] = 'Big'
#         print (row['Country'], df_pop.loc[index,'Size'])

# %% [markdown]
# ### nadwyżki mocy

# %%
plan_2023['nadwyżki OSP %'] = plan_2023['nadwyżki OSP'] / plan_2023['zap']

# %%
plt.figure(figsize = (20,5))

dayList  = plan_2023['Doba']



values_nadwyżki = plan_2023['nadwyżki OSP %']
plt.plot(dayList, values_nadwyżki, linestyle='none', marker='.', markersize=1 )

values_rezerwa = plan_2023['rezerwa %']
plt.plot(dayList, values_rezerwa )



plt.title('rezerwa i nadwyżki %')
plt.legend(['Nadwyżki', 'Wymagana rezerwa'], loc="upper left")


plt.show()

# %%
plan_2023.groupby('Doba', as_index=False)['zap'].max()
# Out:
#           Doba    zap
# 0   2023-01-01  15515
# 1   2023-01-02  20276
# 2   2023-01-03  20822
# 3   2023-01-04  21685
# 4   2023-01-05  21227
# ..         ...    ...
# 360 2023-12-27  24001
# 361 2023-12-28  24094
# 362 2023-12-29  23537
# 363 2023-12-30  21140
# 364 2023-12-31  17508
#
# [365 rows x 2 columns]

# %% [markdown]
# ### niedobór mocy - rozkład godzinowy

# %%
# w jakich godzinach występują niedobory?

# %%
orders = csv_data['orders']

weekday_order = orders.copy()
weekday_order['date'] = pd.to_datetime(weekday_order['date'])
weekday_order['weekday'] = weekday_order['date'].dt.weekday
weekday_order['nameday']=weekday_order['date'].dt.day_name(locale= "pl_PL")

weekday_order.sample(5)

# %%
#niedobory1 = plan_2023[['Doba','Godzina','Niedobór mocy', 'nadwyżki OSP', 'rezerwa']][plan_2023['Niedobór mocy']>0]
niedobory = plan_2023[['Doba','Niedobór mocy', 'nadwyżki OSP', 'rezerwa']][plan_2023['Niedobór mocy']>0]
niedobory
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14292\1864418693.py in <module>
#       1 #niedobory1 = plan_2023[['Doba','Godzina','Niedobór mocy', 'nadwyżki OSP', 'rezerwa']][plan_2023['Niedobór mocy']>0]
# ----> 2 niedobory = plan_2023[['Doba','Niedobór mocy', 'nadwyżki OSP', 'rezerwa']][plan_2023['Niedobór mocy']>0]
#       3 niedobory
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3811             if is_iterator(key):
#    3812                 key = list(key)
# -> 3813             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3814
#    3815         # take() does not accept boolean indexers
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in _get_indexer_strict(self, key, axis_name)
#    6068             keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
#    6069
# -> 6070         self._raise_if_missing(keyarr, indexer, axis_name)
#    6071
#    6072         keyarr = self.take(indexer)
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in _raise_if_missing(self, key, indexer, axis_name)
#    6131
#    6132             not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 6133             raise KeyError(f"{not_found} not in index")
#    6134
#    6135     @overload
#
# KeyError: "['Niedobór mocy'] not in index"

# %%
niedobory = [[plan_2023['Niedobór mocy']>0]]

(
    niedobory
    .groupby('Godzina')
    .count()
    .sort_values(by = 'Niedobór mocy', ascending = False)
)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Niedobór mocy'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14292\4149237546.py in <module>
# ----> 1 niedobory = [plan_2023[plan_2023['Niedobór mocy']>0]]
#       2
#       3 (
#       4     niedobory
#       5     .groupby('Godzina')
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3805             if self.columns.nlevels > 1:
#    3806                 return self._getitem_multilevel(key)
# -> 3807             indexer = self.columns.get_loc(key)
#    3808             if is_integer(indexer):
#    3809                 indexer = [indexer]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
# -> 3804                 raise KeyError(key) from err
#    3805             except TypeError:
#    3806                 # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'Niedobór mocy'

# %%
(
    niedobory
    .groupby('Godzina', as_index = False)['Niedobór mocy']
    .agg([sum,max,min, np.mean])
    .sort_values(by = 'sum', ascending = False)
)
# Out:
#             sum   max   min         mean
# Godzina
# 20       101993  2114    23   784.561538
# 19        94030  2006    32   790.168067
# 18        82823  2007     5   726.517544
# 17        80298  2073    16   757.528302
# 21        79441  2900    15   690.791304
# 16        75561  2005     6   712.839623
# 14        73427  2092     9   719.872549
# 15        71649  2027    12   716.490000
# 13        70600  2156     1   706.000000
# 12        60837  2088     9   640.389474
# 9         55951  2118    15   582.822917
# 10        55926  2200     3   582.562500
# 11        52207  2090    22   593.261364
# 8         26230  2050     2   485.740741
# 22        25365  1996    46   576.477273
# 23         5473  1260     7   342.062500
# 7          2052  1306     4   513.000000
# 24         1212  1190    22   606.000000
# 3          1103  1103  1103  1103.000000
# 4           954   954   954   954.000000
# 6            28    28    28    28.000000

# %%
# boxplot niedoborów miesięcznych

# %%
niedobór_godziny=(
    niedobory
    .groupby('Godzina', as_index = False)['Niedobór mocy']
    .agg([sum,max,min, np.mean])
    .sort_values(by = 'sum', ascending = False)
)
niedobór_godziny.head()
# Out:
#             sum   max  min        mean
# Godzina
# 20       101993  2114   23  784.561538
# 19        94030  2006   32  790.168067
# 18        82823  2007    5  726.517544
# 17        80298  2073   16  757.528302
# 21        79441  2900   15  690.791304

# %%
niedobór_godziny2=(
   
    .groupby(['Doba','Godzina'], as_index = False)['Niedobór mocy'].sum()
)
niedobór_godziny2
# Out:
#            Doba  Godzina  Niedobór mocy
# 0    2023-01-01        3           1103
# 1    2023-01-01        4            954
# 2    2023-01-02       17            235
# 3    2023-01-09       10            251
# 4    2023-01-09       11            228
# ...         ...      ...            ...
# 1485 2023-12-22       16            222
# 1486 2023-12-22       17            305
# 1487 2023-12-22       18            239
# 1488 2023-12-22       19            173
# 1489 2023-12-22       20             90
#
# [1490 rows x 3 columns]

# %%
 niedobory
# Out:
#            Doba  Godzina  Niedobór mocy  nadwyżki OSP  rezerwa
# 2    2023-01-01        3           1103           183     1286
# 3    2023-01-01        4            954           305     1259
# 40   2023-01-02       17            235          1793     2028
# 201  2023-01-09       10            251          1786     2037
# 202  2023-01-09       11            228          1815     2043
# ...         ...      ...            ...           ...      ...
# 8535 2023-12-22       16            222          4027     4249
# 8536 2023-12-22       17            305          4027     4332
# 8537 2023-12-22       18            239          4027     4266
# 8538 2023-12-22       19            173          4027     4200
# 8539 2023-12-22       20             90          4027     4117
#
# [1490 rows x 5 columns]

# %%
plt.figure(figsize = (20,10))
sns.boxplot(data=niedobory, x='Godzina', y='Niedobór mocy')
plt.show()

# %%
plt.figure(figsize = (20,10))
sns.boxplot(data=niedobory, x='Godzina', y='Niedobór mocy')
plt.show()

# %% [markdown]
# ### niedobór mocy w roku 2023

# %%
plt.figure(figsize = (10,5))

niedobory = plan_2023[['Doba','Niedobór mocy', 'nadwyżki OSP', 'rezerwa']][plan_2023['Niedobór mocy']>0]

dayList  = niedobory['Doba']
y_niedobór = niedobory['Niedobór mocy']
y_rezerwa = niedobory['rezerwa']
y_nadwyżki = niedobory['nadwyżki OSP']

plt.plot(dayList, y_niedobór)
#plt.plot(dayList, y_rezerwa)
#plt.plot(dayList, y_nadwyżki)
plt.ylim(0)

plt.title('Niedobór mocy i rezerwa')

plt.fill_between(dayList, y_niedobór)
plt.legend(['Niedobór mocy', 'Wymagana rezerwa'], loc="upper left")



plt.show()

# %%
plt.figure(figsize = (8,5))

plt.title('Niedobór mocy 1')
niedobory = plan_2023[['Doba','Niedobór mocy', 'rezerwa']][plan_2023['Niedobór mocy']>0]
sns.barplot(data=niedobory, x='Doba', y='Niedobór mocy', color ='#666666')


plt.show()

# %%
plan_2023.head(1)
# Out:
#         Doba  Godzina    zap  rezerwa  nadwyżki OSP  moc JW i mag w RB  \
# 0 2023-01-01        1  11823     1294          2713              14578
#
#    moc JW i mag w RB OSP  gen JW i mag w RB  gen JW i mag nie RB  gen wiatr  \
# 0                   7342               4628                 8303       5441
#
#    gen PV  wymiana  niedyspozycje  gen JW nieobjętych OM  OM JRM  \
# 0       0    -1109              0                  11175       0
#
#    Niedobór mocy  rezerwa %  nadwyżki OSP %
# 0          -1419   0.109448        0.229468

# %% [markdown]
# ## Saldo wymiany mocy z zagranicą w dobowym szczycie krajowego zapotrzebowania na moc w poszczególnych dniach 2023 roku.

# %%
plan_2023.to_csv('plan_2023.csv')

# %%
plan_2023.max()
# Out:
# Doba                     2023-12-31 00:00:00
# Godzina                                   24
# zap                                    24809
# rezerwa                                 4466
# nadwyżki OSP                           15049
# moc JW i mag w RB                      25207
# moc JW i mag w RB OSP                  25207
# gen JW i mag w RB                      20939
# gen JW i mag nie RB                    12657
# gen wiatr                               7841
# gen PV                                  6954
# wymiana                                 2942
# niedyspozycje                           1962
# gen JW nieobjętych OM                  19131
# OM JRM                                 23614
# Niedobór mocy                           2900
# rezerwa %                           0.180044
# nadwyżki OSP %                      1.052783
# dtype: object
