# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
URL = 'https://www.pse.pl/dane-systemowe/plany-pracy-kse/plan-koordynacyjny-5-letni/wielkosci-podstawowe'

# %%
page = requests.get(URL)

# %%
page.status_code
# Out:
# 200

# %%
page.ok
# Out:
# True

# %%
page.text
# Out:
# '<!DOCTYPE html> <html class="aui ltr" dir="ltr" lang="pl-PL"> <head> <title>Wielkości podstawowe - PSE</title> <meta content="initial-scale=1.0, width=device-width" name="viewport" /> <meta http-equiv="X-UA-Compatible" content="IE=edge"> <meta id="viewport-meta" name="viewport" content="width=device-width, initial-scale=1"> <meta content="text/html; charset=UTF-8" http-equiv="content-type" /> <link href="https://www.pse.pl/pse-intErnet-theme/images/favicon.ico" rel="Shortcut Icon" /> <link href="https://www.pse.pl/dane-systemowe/plany-pracy-kse/plan-koordynacyjny-5-letni/wielkosci-podstawowe" rel="canonical" /> <link class="lfr-css-file" href="https://www.pse.pl/pse-intErnet-theme/css/aui.css?safeargs=62726f7773657249643d6f74686572267468656d6549643d707365696e7445726e65745f5741525f707365696e7445726e65747468656d65266d696e6966696572547970653d637373266c616e677561676549643d706c5f504c26623d3632303426743d31363731363134343437303030" rel="stylesheet" type="text/css" /> <link href="/html/css/main.css?safeargs=62726f7773657249643d6f74686572267468656d6549643d707365696e7445726e65745f5741525f707365696e7445726e65747468656d65266d696e6966696572547970653d637373266c616e677561676549643d706c5f504c26623d3632303426743d31343437393433303930303030" rel="stylesheet" type="text/css" /> <link href="https://www.pse.pl/menu-portlet/css/main.css?safeargs=62726f7773657249643d6f74686572267468656d6549643d707365696e7445726e65745f5741525f707365696e7445726e65747468656d65266d696e6966696572547970653d637373266c616e677561676549643d706c5f504c26623d3632303426743d31363737363134353931303030" rel="stylesheet" type="text/css" /> <link href="https://www.pse.pl/visioneo-portlet/resources/css/vui-toolbar.css?safeargs=62726f7773657249643d6f74686572267468656d6549643d707365696e7445726e65745f5741525f707365696e7445726e65747468656d65266d696e6966696572547970653d637373266c616e677561676549643d706c5f504c26623d3632303426743d31363737363134353931303030" rel="stylesheet" type="text/css" /> <link href="https://www.pse.pl/WYSIWYG-portlet/css/main.css?safeargs=62726f7773657249643d6f74686572267468656d6549643d707365696e7445726e65745f5741525f707365696e7445726e65747468656d65266d696e6966696572547970653d637373266c616e677561676549643d706c5f504c26623d3632303426743d31363737363134353937303030" rel="stylesheet" type="text/css" /> <link href="https://www.pse.pl/visioneo-portlet/resources/css/theme/jquery-ui.structure.4.0.0.0.css?safeargs=62726f7773657249643d6f74686572267468656d6549643d707365696e7445726e65745f5741525f707365696e7445726e65747468656d65266d696e6966696572547970653d637373266c616e677561676549643d706c5f504c26623d3632303426743d31363737363134353931303030" rel="stylesheet" type="text/css" /> <link href="https://www.pse.pl/visioneo-portlet/resources/css/theme/jquery-ui.theme.4.0.0.0.css?safeargs=62726f7773657249643d6f74686572267468656d6549643d707365696e7445726e65745f5741525f707365696e7445726e65747468656d65266d696e6966696572547970653d637373266c616e677561676549643d706c5f504c26623d3632303426743d31363737363134353931303030" rel="stylesheet" type="text/css" /> <link href="https://www.pse.pl/visioneo-portlet/resources/css/visioneo-core.4.0.0.0.css?safeargs=62726f7773657249643d6f74686572267468656d6549643d707365696e7445726e65745f5741525f707365696e7445726e65747468656d65266d696e6966696572547970653d637373266c616e677561676549643d706c5f504c26623d3632303426743d31363737363134353931303030" rel="stylesheet" type="text/css" /> <link href="https://www.pse.pl/visioneo-portlet/resources/css/visioneo-custom.css?safeargs=62726f7773657249643d6f74686572267468656d6549643d707365696e7445726e65745f5741525f707365696e7445726e65747468656d65266d696e6966696572547970653d637373266c616e677561676549643d706c5f504c26623d3632303426743d31363737363134353931303030" rel="stylesheet" type="text/css" /> <link href="https://www.pse.pl/visioneo-portlet/resources/css/jqpagination.css?safeargs=62726f7773657249643d6f74686572267468656d6549643d707365696e7445726e65745f5741525f707365696e7445726e65747468656d65266d696e6966696572547970653d637373266c616e677561 ...

# %%
soup = BeautifulSoup(page.text, 'html.parser')

# %%
sopu.text
